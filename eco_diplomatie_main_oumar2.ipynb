# %% [markdown]
# # Eco-diplomatie - Team FOWAC

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn import preprocessing

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

from IPython.display import display_html
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# ### Import dataset & traitements valeurs manquantes

# %%
# Import dataset avec exclusion header & footer
df = pd.read_excel('DATABASE.xls', index_col=0, skiprows=[0,1,2], skipfooter=42) 

# Rename columns
df = df.rename(columns={'Sender c': 'Sender1', 
                        'Sender 2c': 'Sender2', 
                        'Sender 3c': 'Sender3', 
                        'Targetd': 'Target',
                        'US casee': 'US_case', 
                        'US unilateral casef': 'US_unilateral_case', 
                        'Foreign policy goal categoryg': 'Goal_categ', 
                        'First yearh': 'First_year',
                        'Last yeari': 'Last_year', 
                        'Policy resultj': 'Policy_result', 
                        'Sanctions contributionk': 'Sanctions_contrib',
                        'Success \nscorel': 'Success_score', 
                        'Companion policiesm': 'Comp_policies', 
                        'International cooperationn':'Int_coop', 
                        'International assistanceo': 'Int_assistance', 
                        'Cooperating international organizationp': 'Coop_int_org',
                        'International organization senderq': 'Int_org_sender', 
                        'International organization sender & target membersr': 'Int_org_sender_&_target_members', 
                        'Length (years)s': 'Length_years',
                        'Prior relationst': 'Prior_relations', 
                        'Regime Type \n(DEMOC 1st year)u': 'Regime_type', 
                        'Regime Type2 (Polity2 1st year)v': 'Regime_type2', 
                        'Regime Type3 \n(Scale 1st year)w': 'Regime_type3',
                        'Political stability priorx': 'Political_stability_prior', 
                        'Political stability duringy': 'Political_stability_during',
                        'Cost to targetz': 'Cost_to_target', 
                        'Cost to target (percent of GNP)aa': 'Cost_to_target_%GNP',
                        'Cost to target per capitabb': 'Cost_to_target_per_capita', 
                        'Trade linkagecc': 'Trade_linkage', 
                        'GNP \nratiodd': 'GNP_ratio',
                        'Health and stabilityee': 'Health_&_stability', 
                        'Sanction typeff': 'Sanction_type', 
                        'Cost to sendergg': 'Cost_to_sender',
                        'GDP growth (percent, 5-year average)hh': 'GDP_growth%5years_average', 
                        'Inflation (percent,\n 3-year average)ii':'Inflation%3years_average', 
                        'Target International Monetary Fund codejj': 'Target_int_monetary_code', 
                        'Country groupkk': 'Country_group'
                       })
# rename index
df.index.names = ['id_case']

# Remplacement des '--' en 0 puis conversion en numérique
df['Cost_to_target_%GNP'] = df['Cost_to_target_%GNP'].astype('str')
df['Cost_to_target_%GNP'] = df['Cost_to_target_%GNP'].str.replace('--', '0')
df['Cost_to_target_%GNP'] = pd.to_numeric(df['Cost_to_target_%GNP'])

# # Remplacement des '--' en 0 puis conversion en numérique
df['Cost_to_target'] = df['Cost_to_target'].astype('str')
df['Cost_to_target'] = df['Cost_to_target'].str.replace('--', '0')
df['Cost_to_target'] = pd.to_numeric(df['Cost_to_target'])

# # Remplacement des '--' en 0 puis conversion en numérique
df['Cost_to_target_per_capita'] = df['Cost_to_target_per_capita'].astype('str')
df['Cost_to_target_per_capita'] = df['Cost_to_target_per_capita'].str.replace('--', '0')
df['Cost_to_target_per_capita'] = pd.to_numeric(df['Cost_to_target_per_capita'])

# df[['Cost_to_target_%GNP', 'Cost_to_target', 'Cost_to_target_per_capita']].dtypes

#  remplacement des n.a. par NaN
df['GDP_growth%5years_average'] = df['GDP_growth%5years_average'].astype('str')
df['GDP_growth%5years_average'] = df['GDP_growth%5years_average'].str.replace('n.a.', '')
df['GDP_growth%5years_average'] = pd.to_numeric(df['GDP_growth%5years_average'])

df['GDP_growth%5years_average'].head()
# df['GDP_growth%5years_average'].dtypes
# df['GDP_growth%5years_average'].isna().sum()

# Suppression de la virgule '--' restent tels quels
df['Comp_policies'] = df['Comp_policies'].str.replace(',', '')
# df['Comp_policies'].head()

# %%
df.head()
# Out:
#                    Sender1 Sender2 Sender3      Target                             Goal  US_case  US_unilateral_case  Goal_categ  First_year Last_year  Policy_result  Sanctions_contrib  Success_score Comp_policies  Int_coop Int_assistance Coop_int_org  Int_org_sender  Int_org_sender_&_target_members  Length_years  Prior_relations Regime_type Regime_type2 Regime_type3 Political_stability_prior Political_stability_during  Cost_to_target  Cost_to_target_%GNP  Cost_to_target_per_capita Trade_linkage  GNP_ratio  Health_&_stability Sanction_type  Cost_to_sender  GDP_growth%5years_average Inflation%3years_average Target_int_monetary_code  Country_group
# id_case
# 14-1        UNITED KINGDOM     NaN     NaN     GERMANY                 Military victory        0                   0           4        1914      1918              4                  3             12             R         4              A           --               0                                0             4                1           5            2            2                         0                          0           843.0                  7.1                      12.58             9        1.0                   3         F,X,M               4                       3.58                  2.86667                      134              1
# 17-1         UNITED STATES     NaN     NaN       JAPAN              Shipping for Allies        1                   1           5        1917      1918              2                  2              4            --         1             --           --               0                                0             1                2           5            1            2                         0                          0            23.0                  0.8                       0.44          20.5       13.0                   3             X               2                       5.40                     25.6                      158              1
# 18-1        UNITED KINGDOM     NaN     NaN      RUSSIA           Destabilize Bolsheviks        0                   0           2        1918      1920              1                  2              2            RQ         4             --           --               0                                0             2                1           1           -1            2                       0.1                          0           446.0                  4.1                       2.49          18.5        1.0                   1         F,X,M               3                        NaN                     n.a.                      922              2
# 21-1     LEAGUE OF NATIONS     NaN     NaN  YUGOSLAVIA  Military disruption vs. Albania        0                   0           3        1921      1921              4                  4             16            --         4             --           --               1                                1             1                2           3            0            2                       0.4                          0             0.0                  0.0                       0.00          26.5       37.0                   2            --               2                      -1.50                     n.a.                      188              2
# 25-1     LEAGUE OF NATIONS     NaN     NaN      GREECE           Withdraw from Bulgaria        0                   0           3        1925      1925              4                  4             16            --         4             --           --               1                                1             1                2           0           -6            1                       0.9                          0             0.0                  0.0                       0.00            36       56.0                   2            --               2                       3.30                     48.8                      174              1

# %% [markdown]
# ### Variables Quantitatives et Qualitatives

# %%
# display side by side
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# display categoric & quantiv vars
df_categ = df.select_dtypes(include=['object']).columns
df_quant = df.select_dtypes(include=['int','float64']).columns
quant = pd.DataFrame.from_dict({'Numeric_var': df_quant})
categ = pd.DataFrame.from_dict({'Categ_vars': df_categ})
display_side_by_side(quant,categ)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Numeric_var</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>US_case</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>US_unilateral_case</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Goal_categ</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>First_year</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Policy_result</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Sanctions_contrib</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Success_score</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Int_coop</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Int_org_sender</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Int_org_sender_&amp;_target_members</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Length_years</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Prior_relations</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Cost_to_target</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Cost_to_target_%GNP</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Cost_to_target_per_capita</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>GNP_ratio</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Health_&amp;_stability</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Cost_to_sender</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>GDP_growth%5years_average</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Country_group</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Categ_vars</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sender1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Sender2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Sender3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Target</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Goal</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Last_year</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Comp_policies</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Int_assistance</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Coop_int_org</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Regime_type</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Regime_type2</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Regime_type3</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Political_stability_prior</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Political_stability_during</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Trade_linkage</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Sanction_type</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Inflation%3years_average</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Target_int_monetary_code</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# ### Describe Numeric Variables

# %%
# list quantiv variables
df_quant = df.select_dtypes(include=['int','float64'])
list(df.select_dtypes(include=['int','float64']).columns)
df_quant.describe()
# Out:
#           US_case  US_unilateral_case  Goal_categ   First_year  Policy_result  Sanctions_contrib  Success_score    Int_coop  Int_org_sender  Int_org_sender_&_target_members  Length_years  Prior_relations  Cost_to_target  Cost_to_target_%GNP  Cost_to_target_per_capita     GNP_ratio  Health_&_stability  Cost_to_sender  GDP_growth%5years_average  Country_group
# count  204.000000          204.000000  204.000000   204.000000     204.000000         204.000000     204.000000  204.000000      204.000000                       204.000000    204.000000       204.000000      204.000000           204.000000                 204.000000    204.000000          204.000000      204.000000                 186.000000     204.000000
# mean     0.686275            0.348039    2.651961  1975.279412       2.642157           2.446078       6.926471    2.093137        0.254902                         0.220588      7.053922         2.098039      457.345015             2.671495                  30.659529   1910.267549            1.995098        1.941176                   3.184562       3.495098
# std      0.465148            0.477520    1.383024    19.239619       1.120515           0.757253       4.171152    1.085576        0.436878                         0.415663      9.626627         0.749513     2045.643232             6.578428                 118.860966   6811.603934            0.752648        0.804220                   4.660725       1.729197
# min      0.000000            0.000000    1.000000  1914.000000       1.000000           1.000000       1.000000    1.000000        0.000000                         0.000000      1.000000         1.000000     -182.000000            -6.300000                  -6.450000      0.040000            1.000000        1.000000                 -18.980000       1.000000
# 25%      0.000000            0.000000    2.000000  1963.000000       2.000000           2.000000       4.000000    1.000000        0.000000                         0.000000      1.000000         2.000000        9.937500             0.040000                   0.400000     13.750000            1.000000        1.000000                   1.420000       2.000000
# 50%      1.000000            0.000000    2.000000  1979.000000       3.000000           2.000000       6.000000    2.000000        0.000000                         0.000000      3.500000         2.000000       54.500000             0.700000                   2.435000    104.500000            2.000000        2.000000                   3.282222       3.000000
# 75%      1.000000            1.000000    4.000000  1991.000000       4.000000           3.000000       9.000000    3.000000        1.000000                         0.000000      7.000000         3.000000      213.250000             2.600000                  11.417500    577.725000            3.000000        2.000000                   5.310000       5.000000
# max      1.000000            1.000000    5.000000  2002.000000       4.000000           4.000000      16.000000    4.000000        1.000000                         1.000000     60.000000         3.000000    18800.000000            54.000000                1093.000000  50869.000000            3.000000        4.000000                  33.340000       6.000000

# %% [markdown]
# ## 4. Visualisations

# %% [markdown]
# ### Principaux auteurs de sanctions

# %%
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(8, 10))

# Plot 
sns.set_color_codes("muted")
sns.barplot(x=df['Sender1'].value_counts(), y=df['Sender1'].value_counts().index)

# Add a legend and informative axis label
ax.set(xlim=(0, 30), ylabel="", xlabel="Quantités de sanctions")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ### Principaux motifs de sanctions

# %%
# Initialize matplotlib figure
f, ax = plt.subplots(figsize=(8, 10))

# Plot 
sns.set_color_codes("muted")
sns.barplot(x=df['Goal'].value_counts()[:30], y=df['Goal'].value_counts()[:30].index)

# Add a legend and informative axis label
ax.set(xlim=(0, 10), ylabel="", xlabel="Occurrences de motifs de sanctions")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ### Pays les plus impactés financièrement par les sanctions (Cost_to_target)

# %%
df_costs = df[['Target', 'Cost_to_target']].groupby(['Target']).sum().sort_values(by='Cost_to_target', ascending=False)
df_costs['Cost_to_target'].head()

X = df_costs['Cost_to_target'].values #returns a numpy array
scaler = preprocessing.MinMaxScaler(feature_range=(0, 10))
df_costs['costs'] = scaler.fit_transform(X.reshape(-1,1))
# df_costs[:5]  

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 8))

# Plot 
sns.set_color_codes("muted")
sns.barplot(x=df_costs[:20].costs, y=df_costs[:20].index)

# Add a legend and informative axis label
ax.set(xlim=(0, 10), ylabel="", xlabel="Couts des sanctions par pays (échelle de 0 à 10)")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ### Pays les plus impactés financièrement par les sanctions (Cost_to_target_per_capita)

# %%
df_costs_capita = df[['Target', 'Cost_to_target_per_capita']].groupby(['Target']).sum().sort_values(by='Cost_to_target_per_capita', ascending=False)
# df_costs_capita[:20]  

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(10, 8))

# Plot 
sns.set_color_codes("muted")
sns.barplot(x=df_costs_capita[:20].Cost_to_target_per_capita, y=df_costs_capita[:20].index)

# Add a legend and informative axis label
ax.set(xlim=(0, 1500), ylabel="", xlabel="Couts des sanctions par pays (Cost_to_target_per_capita)")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ## Partie modélisation

# %%
# Defining X as all variables different from 'Success score', 'Policy result' and 'sanction contriution' and dropping 
# the last two as they are correlated with the first one.
data_table = df.drop(['Policy_result', 'Sanctions_contrib'], axis=1)

# Copying 'Success score' column then dropping the first (to have it as last column)
data_table['Success score'] = data_table['Success_score']
data_table = data_table.drop(['Success_score'], axis=1)

# Replacing remaining inconsistent values ('--' and 'n.a.') for MLP classifier
data_table = data_table.replace(to_replace='--', value= None)
data_table = data_table.replace(to_replace='n.a.', value= None)

# Dropping 'Sender 2/3' columns as they have lot of NaNs
data_table = data_table.drop(['Sender2','Sender3'], axis =1)

data_table.head()
# Out:
#                    Sender1      Target                             Goal  US_case  US_unilateral_case  Goal_categ  First_year Last_year Comp_policies  Int_coop Int_assistance Coop_int_org  Int_org_sender  Int_org_sender_&_target_members  Length_years  Prior_relations Regime_type Regime_type2 Regime_type3 Political_stability_prior Political_stability_during  Cost_to_target  Cost_to_target_%GNP  Cost_to_target_per_capita Trade_linkage  GNP_ratio  Health_&_stability Sanction_type  Cost_to_sender  GDP_growth%5years_average Inflation%3years_average Target_int_monetary_code  Country_group  Success score
# id_case
# 14-1        UNITED KINGDOM     GERMANY                 Military victory        0                   0           4        1914      1918             R         4              A           --               0                                0             4                1           5            2            2                         0                          0           843.0                  7.1                      12.58             9        1.0                   3         F,X,M               4                       3.58                  2.86667                      134              1             12
# 17-1         UNITED STATES       JAPAN              Shipping for Allies        1                   1           5        1917      1918             R         1              A           --               0                                0             1                2           5            1            2                         0                          0            23.0                  0.8                       0.44          20.5       13.0                   3             X               2                       5.40                     25.6                      158              1              4
# 18-1        UNITED KINGDOM      RUSSIA           Destabilize Bolsheviks        0                   0           2        1918      1920            RQ         4              A           --               0                                0             2                1           1           -1            2                       0.1                          0           446.0                  4.1                       2.49          18.5        1.0                   1         F,X,M               3                        NaN                     25.6                      922              2              2
# 21-1     LEAGUE OF NATIONS  YUGOSLAVIA  Military disruption vs. Albania        0                   0           3        1921      1921            RQ         4              A           --               1                                1             1                2           3            0            2                       0.4                          0             0.0                  0.0                       0.00          26.5       37.0                   2            --               2                      -1.50                     25.6                      188              2             16
# 25-1     LEAGUE OF NATIONS      GREECE           Withdraw from Bulgaria        0                   0           3        1925      1925            RQ         4              A           --               1                                1             1                2           0           -6            1                       0.9                          0             0.0                  0.0                       0.00            36       56.0                   2            --               2                       3.30                     48.8                      174              1             16

# %% [markdown]
# #### Encodage de variables catégorielles en variables numériques

# %%
lb_make = LabelEncoder()

# Transforming categorical values to numeeric values
for c in data_table.columns:
    if(data_table[c].dtype == 'O'):
        data_table[c] = lb_make.fit_transform(data_table[c])
        #print(type(c))   

data_table.head()
# Out:
#          Sender1  Target  Goal  US_case  US_unilateral_case  Goal_categ  First_year  Last_year  Comp_policies  Int_coop  Int_assistance  Coop_int_org  Int_org_sender  Int_org_sender_&_target_members  Length_years  Prior_relations  Regime_type  Regime_type2  Regime_type3  Political_stability_prior  Political_stability_during  Cost_to_target  Cost_to_target_%GNP  Cost_to_target_per_capita  Trade_linkage  GNP_ratio  Health_&_stability  Sanction_type  Cost_to_sender  GDP_growth%5years_average  Inflation%3years_average  Target_int_monetary_code  Country_group  Success score
# id_case
# 14-1          21      43   105        0                   0           4        1914          0              4         4               0             0               0                                0             4                1            7            13             1                          0                           0           843.0                  7.1                      12.58             27        1.0                   3              4               4                       3.58                        27                         3              1             12
# 17-1          23      60   130        1                   1           5        1917          0              4         1               0             0               0                                0             1                2            7            12             1                          0                           0            23.0                  0.8                       0.44             50       13.0                   3              6               2                       5.40                       113                         7              1              4
# 18-1          21      96    37        0                   0           2        1918          1              5         4               0             0               0                                0             2                1            3            10             1                          1                           0           446.0                  4.1                       2.49             45        1.0                   1              4               3                        NaN                       113                        87              2              2
# 21-1          13     122    98        0                   0           3        1921          2              5         4               0             0               1                                1             1                2            5            11             1                          4                           0             0.0                  0.0                       0.00             61       37.0                   2              0               2                      -1.50                       113                        13              2             16
# 25-1          13      45   139        0                   0           3        1925          3              5         4               0             0               1                                1             1                2            2             5             0                          8                           0             0.0                  0.0                       0.00             73       56.0                   2              0               2                       3.30                       126                         9              1             16

# %% [markdown]
# #### Partie entrainement  (supervisée):
# ##### Avec modèle NN

# %%
# Filling null values with 0
data_table = data_table.fillna(0)

# Splitting data for training and test set
X, y = data_table.iloc[:,:33], data_table['Success score']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# Choosing MLP classifier for NN
mlp = MLPClassifier(random_state=42)
mlp.fit(X_train, y_train)

print("Neural network model accuracy (discrete target variable) :")
print("Accuracy on training set : {:.2f}".format(mlp.score(X_train, y_train)))
print("Accuracy on test set : {:.2f}".format(mlp.score(X_test, y_test)))
# Out:
# Neural network model accuracy (discrete target variable) :
# Accuracy on training set : 0.49
# Accuracy on test set : 0.13

# %% [markdown]
# ##### Réentrainement du modèle NN avec un changement de la variable cible "Success score" en variable booléenne

# %%
# If 'Success score' >=9, y=1, y=0 otherwise. 
yb = [0 if(i<9) else 1 for i in y]

X_train, X_test, y_train, y_test = train_test_split(X, yb, test_size=0.33, random_state=0)

mlp = MLPClassifier(random_state=42)
mlp.fit(X_train, y_train)

print("Neural network model accuracy (boolean target variable) :")
print("Accuracy on training set : {:.2f}".format(mlp.score(X_train, y_train)))
print("Accuracy on test set : {:.2f}".format(mlp.score(X_test, y_test)))
# Out:
# Neural network model accuracy (boolean target variable) :
# Accuracy on training set : 0.62
# Accuracy on test set : 0.59

# %% [markdown]
# On peut voir que les résultats sont meilleurs avec une variable boolénenne comme cible.

# %% [markdown]
# ##### Avec modèle arbre de décision

# %%
tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train, y_train)

print("Decision tree model accuracy :")
print("Accuracy on training set : {:.3f}".format(tree.score(X_train, y_train)))
print("Accuracy on test set : {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# Decision tree model accuracy :
# Accuracy on training set : 1.000
# Accuracy on test set : 0.603

# %% [markdown]
# Meilleurs résultats qu'avec un modèle NN.

# %% [markdown]
# ##### Avec modèle arbre de décision : Feature importance

# %%
print("Feature importances:\n{}".format(tree.feature_importances_))
# Out:
# Feature importances:
# [0.         0.02761844 0.22153799 0.         0.         0.01609848
#  0.04273201 0.01408617 0.         0.         0.         0.01609848
#  0.         0.         0.07214441 0.07317493 0.         0.
#  0.         0.         0.02146465 0.02861953 0.08341785 0.15725325
#  0.02367424 0.         0.         0.         0.         0.03577441
#  0.07991653 0.08638861 0.        ]

# %%
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Plot 
sns.set_color_codes("muted")
sns.barplot(x= tree.feature_importances_, y = data_table.columns[:33])

# Add a legend and informative axis label
ax.set(xlim=(0, 0.3), ylabel="Feature", xlabel="Feature importance")
sns.despine(left=True, bottom=True)

# %% [markdown]
# #### Avec modèle Random forest :

# %%
forest = RandomForestClassifier(n_estimators=100, random_state=0)
forest.fit(X_train, y_train)

print("Random forest model accuracy :")
print("Accuracy on training set : {:.3f}".format(forest.score(X_train, y_train)))
print("Accuracy on test set : {:.3f}".format(forest.score(X_test, y_test)))
# Out:
# Random forest model accuracy :
# Accuracy on training set : 1.000
# Accuracy on test set : 0.735

# %% [markdown]
# # SUITE

# %%
data_table.head(10)
# Out:
#          Sender1  Target  Goal  US_case  US_unilateral_case  Goal_categ  First_year  Last_year  Comp_policies  Int_coop  Int_assistance  Coop_int_org  Int_org_sender  Int_org_sender_&_target_members  Length_years  Prior_relations  Regime_type  Regime_type2  Regime_type3  Political_stability_prior  Political_stability_during  Cost_to_target  Cost_to_target_%GNP  Cost_to_target_per_capita  Trade_linkage  GNP_ratio  Health_&_stability  Sanction_type  Cost_to_sender  GDP_growth%5years_average  Inflation%3years_average  Target_int_monetary_code  Country_group  Success score
# id_case
# 14-1          21      43   105        0                   0           4        1914          0              4         4               0             0               0                                0             4                1            7            13             1                          0                           0         843.000                7.100                     12.580             27        1.0                   3              4               4                       3.58                        27                         3              1             12
# 17-1          23      60   130        1                   1           5        1917          0              4         1               0             0               0                                0             1                2            7            12             1                          0                           0          23.000                0.800                      0.440             50       13.0                   3              6               2                       5.40                       113                         7              1              4
# 18-1          21      96    37        0                   0           2        1918          1              5         4               0             0               0                                0             2                1            3            10             1                          1                           0         446.000                4.100                      2.490             45        1.0                   1              4               3                       0.00                       113                        87              2              2
# 21-1          13     122    98        0                   0           3        1921          2              5         4               0             0               1                                1             1                2            5            11             1                          4                           0           0.000                0.000                      0.000             61       37.0                   2              0               2                      -1.50                       113                        13              2             16
# 25-1          13      45   139        0                   0           3        1925          3              5         4               0             0               1                                1             1                2            2             5             0                          8                           0           0.000                0.000                      0.000             73       56.0                   2              0               2                       3.30                       126                         9              1             16
# 32-1          13       4   129        0                   0           3        1932          5              5         3               0             0               1                                1             3                2            6            13             1                          0                           0           2.500                2.600                      0.800            103      322.0                   2              6               2                       0.00                       126                        18              3              6
# 32-1          13      89   129        0                   0           3        1932          5              5         3               0             0               1                                1             3                2            3             8             1                          0                           0           0.001                0.001                      0.001             98      735.0                   2              6               2                       0.00                       126                        30              3              6
# 33-1          21     119   120        0                   0           1        1933          4              5         1               0             0               0                                0             1                1            2             1             0                          0                           0           4.000                0.020                      0.020             35        1.0                   2              5               2                       2.35                       126                       100              2             12
# 35-1          13      58   138        0                   0           3        1935          6              5         4               0             0               1                                1             1                2            2             1             0                          3                           0          86.000                1.700                      1.980             41        6.0                   3              4               3                      -0.52                         0                         4              1              2
# 38-1          23      77    58        1                   0           1        1938          9              5         2               0             0               0                                0             9                2            2             5             0                          1                           0           2.000                0.200                      0.110            106       75.0                   3              2               2                       7.38                        19                        27              3              9

# %%
data_table.columns
# Out:
# Index(['Sender1', 'Target', 'Goal', 'US_case', 'US_unilateral_case', 'Goal_categ', 'First_year', 'Last_year', 'Comp_policies', 'Int_coop', 'Int_assistance', 'Coop_int_org', 'Int_org_sender', 'Int_org_sender_&_target_members', 'Length_years', 'Prior_relations', 'Regime_type', 'Regime_type2', 'Regime_type3', 'Political_stability_prior', 'Political_stability_during', 'Cost_to_target', 'Cost_to_target_%GNP', 'Cost_to_target_per_capita', 'Trade_linkage', 'GNP_ratio', 'Health_&_stability', 'Sanction_type', 'Cost_to_sender', 'GDP_growth%5years_average', 'Inflation%3years_average', 'Target_int_monetary_code', 'Country_group', 'Success score'], dtype='object')

# %%
data_table = data_table.drop(['Case no.b', 'US_case','Sender1','Target','US_unilateral_case',
                              'Goal','First_year','Last_year','Int_org_sender'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-838fb0b44a80> in <module>
#       1 data_table = data_table.drop(['Case no.b', 'US_case','Sender1','Target','US_unilateral_case',
# ----> 2                               'Goal','First_year','Last_year','Int_org_sender'], axis=1)
#
# ~/anaconda3/envs/data-science/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/anaconda3/envs/data-science/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/anaconda3/envs/data-science/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/anaconda3/envs/data-science/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['Case no.b'] not found in axis"

# %%
nbre_col = data_table.shape[1] - 1
nbre_col
# Out:
# 33

# %%
# Splitting data for training and test set
X, y = data_table.iloc[:,:nbre_col], data_table['Success score']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# ### Histogramme

# %%
# Histogramme
data_table['Success score'].hist(density=True)
#df.std_wtd.plot.hist(bins=12, alpha=0.5)
# Histogramme plus beau
#df[df.std_wtd.abs() < 100]["std_wtd"].hist(density=True,bins=20)
plt.show()

# %%
data_table['Success score'].value_counts(normalize=True).plot(kind='pie')

# %%
df_correlation = data_table[["Success score", "Inflation%3years_average", "Target_int_monetary_code",
                            "GDP_growth%5years_average","Cost_to_sender","Sanction_type"]]
corr = df_correlation.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col1 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col3 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col4 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col0 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col2 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col5 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col1 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col4 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow3_col0 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow3_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow3_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow3_col4 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow3_col5 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow4_col0 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow4_col2 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow4_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow4_col5 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow5_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow5_col1 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow5_col2 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow5_col3 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow5_col4 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Success score</th>        <th class="col_heading level0 col1" >Inflation%3years_average</th>        <th class="col_heading level0 col2" >Target_int_monetary_code</th>        <th class="col_heading level0 col3" >GDP_growth%5years_average</th>        <th class="col_heading level0 col4" >Cost_to_sender</th>        <th class="col_heading level0 col5" >Sanction_type</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7blevel0_row0" class="row_heading level0 row0" >Success score</th>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col1" class="data row0 col1" >0.09</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col2" class="data row0 col2" >-0.22</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col3" class="data row0 col3" >-0.02</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col4" class="data row0 col4" >-0.12</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow0_col5" class="data row0 col5" >-0.21</td>
#             </tr>
#             <tr>
#                         <th id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7blevel0_row1" class="row_heading level0 row1" >Inflation%3years_average</th>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col0" class="data row1 col0" >0.09</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col2" class="data row1 col2" >0.04</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col3" class="data row1 col3" >-0.10</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col4" class="data row1 col4" >-0.13</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow1_col5" class="data row1 col5" >-0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7blevel0_row2" class="row_heading level0 row2" >Target_int_monetary_code</th>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col0" class="data row2 col0" >-0.22</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col1" class="data row2 col1" >0.04</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col3" class="data row2 col3" >-0.16</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col4" class="data row2 col4" >0.03</td>
#                         <td id="T_269c6086_8a87_11ea_9b94_d4bed96d0c7brow2_col5" class="data row2 col5" >0.01</td>
#             </tr>
#             <tr>

# %%
df_correlation = data_table[["Success score","Cost_to_target","Cost_to_target_%GNP","Cost_to_target_per_capita",
                             "Trade_linkage","GNP_ratio","Regime_type2"]]
corr = df_correlation.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col2 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col3 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col4 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col5 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col6 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow1_col2 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow1_col3 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow1_col4 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow1_col5 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow1_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow2_col0 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow2_col1 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow2_col3 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow2_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow2_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow2_col6 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow3_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow3_col1 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow3_col2 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow3_col4 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow3_col5 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow3_col6 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow4_col0 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow4_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow4_col2 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow4_col3 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow4_col5 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow5_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow5_col1 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow5_col2 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow5_col3 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow5_col4 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow5_col6 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow6_col0 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow6_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow6_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow6_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Success score</th>        <th class="col_heading level0 col1" >Cost_to_target</th>        <th class="col_heading level0 col2" >Cost_to_target_%GNP</th>        <th class="col_heading level0 col3" >Cost_to_target_per_capita</th>        <th class="col_heading level0 col4" >Trade_linkage</th>        <th class="col_heading level0 col5" >GNP_ratio</th>        <th class="col_heading level0 col6" >Regime_type2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7blevel0_row0" class="row_heading level0 row0" >Success score</th>
#                         <td id="T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col1" class="data row0 col1" >-0.07</td>
#                         <td id="T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col2" class="data row0 col2" >0.03</td>
#                         <td id="T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col3" class="data row0 col3" >-0.04</td>
#                         <td id="T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col4" class="data row0 col4" >0.16</td>
#                         <td id="T_26ffdeba_8a87_11ea_82bd_d4bed96d0c7brow0_col5" class="data row0 col5" >-0.01</td>

# %%
print(data_table.shape)
data_table.head()
# Out:
# (204, 35)
#          Case no.b  Sender1  Target  Goal  US_case  US_unilateral_case  Goal_categ  First_year  Last_year  Comp_policies  Int_coop  Int_assistance  Coop_int_org  Int_org_sender  Int_org_sender_&_target_members  Length_years  Prior_relations  Regime_type  Regime_type2  Regime_type3  Political_stability_prior  Political_stability_during  Cost_to_target  Cost_to_target_%GNP  Cost_to_target_per_capita  Trade_linkage  GNP_ratio  Health_&_stability  Sanction_type  Cost_to_sender  GDP_growth%5years_average  Inflation%3years_average  Target_int_monetary_code  Country_group  Success score
# id_case
# 0                1       21      43   105        0                   0           4        1914          0              4         4               0             0               0                                0             4                1            7            13             1                          0                           0           843.0                  7.1                      12.58             27        1.0                   3              4               4                       3.58                        27                         3              1             12
# 1                2       23      60   130        1                   1           5        1917          0              4         1               0             0               0                                0             1                2            7            12             1                          0                           0            23.0                  0.8                       0.44             50       13.0                   3              6               2                       5.40                       113                         7              1              4
# 2                3       21      96    37        0                   0           2        1918          1              5         4               0             0               0                                0             2                1            3            10             1                          1                           0           446.0                  4.1                       2.49             45        1.0                   1              4               3                       0.00                       113                        87              2              2
# 3                4       13     122    98        0                   0           3        1921          2              5         4               0             0               1                                1             1                2            5            11             1                          4                           0             0.0                  0.0                       0.00             61       37.0                   2              0               2                      -1.50                       113                        13              2             16
# 4                5       13      45   139        0                   0           3        1925          3              5         4               0             0               1                                1             1                2            2             5             0                          8                           0             0.0                  0.0                       0.00             73       56.0                   2              0               2                       3.30                       126                         9              1             16

# %% [markdown]
# ### LASSO

# %%
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### Alpha (ou lambda qui est ici le coefficient de pénalité)

# %%
#generer un alpha quelconque pour test 
alphas = 10**np.linspace(10,-2,100)*0.5
#alphas

# %% [markdown]
# #### Coefficients

# %%
#générer une boucle pour récupérer les coeffs
lasso = Lasso(max_iter = 10000, normalize = True)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(scale(X_train), y_train)
    coefs.append(lasso.coef_)

# %% [markdown]
# #### représentation graphique du modèle

# %%
ax = plt.gca()
ax.plot(alphas*2, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
# Out:
# Text(0, 0.5, 'weights')

# %% [markdown]
# #### fit et prediction

# %%
lassocv = LassoCV(alphas = None, cv = 10, max_iter = 100000, normalize = True)
lassocv.fit(X_train, y_train)

lasso.set_params(alpha=lassocv.alpha_)
lasso.fit(X_train, y_train)

print("---------------------------")
pred = lasso.predict(X_test)
print(pred)
print("---------------------------")
print("MSE est : ", mean_squared_error(y_test, pred))
# mean_squared_error(y_test, lasso.predict(X_test))
# Out:
# ---------------------------
# [0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118 0.35294118 0.35294118 0.35294118 0.35294118
#  0.35294118 0.35294118]
# ---------------------------
# MSE est :  0.21972318339100344

# %%
#print("LASSO :")
#print("Accuracy on training set : {:.3f}".format(lassocv.score(X_train, y_train)))
#print("Accuracy on test set : {:.3f}".format(lassocv.score(X_test, y_test)))

# %%
# on récupère les coefficients obtenus avec le modèle
# certains coefficcients sont maintenant réduit à 0
pd.Series(lasso.coef_, index=X.columns)
# Out:
# Case no.b                          0.000000e+00
# Sender1                           -0.000000e+00
# Target                            -0.000000e+00
# Goal                               0.000000e+00
# US_case                           -0.000000e+00
# US_unilateral_case                -0.000000e+00
# Goal_categ                        -0.000000e+00
# First_year                        -0.000000e+00
# Last_year                         -0.000000e+00
# Comp_policies                     -0.000000e+00
# Int_coop                          -0.000000e+00
# Int_assistance                     0.000000e+00
# Coop_int_org                      -0.000000e+00
# Int_org_sender                     0.000000e+00
# Int_org_sender_&_target_members    0.000000e+00
# Length_years                      -0.000000e+00
# Prior_relations                    0.000000e+00
# Regime_type                        0.000000e+00
# Regime_type2                       8.081980e-18
# Regime_type3                       0.000000e+00
# Political_stability_prior         -0.000000e+00
# Political_stability_during        -0.000000e+00
# Cost_to_target                     0.000000e+00
# Cost_to_target_%GNP                0.000000e+00
# Cost_to_target_per_capita          0.000000e+00
# Trade_linkage                      0.000000e+00
# GNP_ratio                         -0.000000e+00
# Health_&_stability                -0.000000e+00
# Sanction_type                     -0.000000e+00
# Cost_to_sender                    -0.000000e+00
# GDP_growth%5years_average         -0.000000e+00
# Inflation%3years_average           0.000000e+00
# Target_int_monetary_code          -0.000000e+00
# dtype: float64

# %% [markdown]
# ### RIDGE

# %%
#methode de Ridge
ridge = Ridge(normalize = True)
coefs = []

for a in alphas:
    ridge.set_params(alpha = a)
    ridge.fit(X, y)   #reduction
    coefs.append(ridge.coef_)    
np.shape(coefs)
# Out:
# (100, 33)

# %% [markdown]
# #### représentation graphique du modèle

# %%
ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
# Out:
# Text(0, 0.5, 'weights')

# %% [markdown]
# #### réduction du modèle et MSE

# %%
## alpha = 4 par défaut
ridge2 = Ridge(alpha = 4, normalize = True)
ridge2.fit(X_train, y_train)             # donnees d'apprentissage

pred2 = ridge2.predict(X_test)           # prediction sur l'échantillon test 
print(" Les coeffients ")
print(pd.Series(ridge2.coef_, index = X.columns)) # les coefficients obtenus avec la méthode de Ridge
print("----------------------")
print("MSE est :", mean_squared_error(y_test, pred2))          # MSE
# Out:
#  Les coeffients
# Case no.b                          0.000041
# Sender1                           -0.000891
# Target                            -0.000250
# Goal                               0.000243
# US_case                            0.007208
# US_unilateral_case                -0.014906
# Goal_categ                        -0.008545
# First_year                        -0.000109
# Last_year                         -0.000301
# Comp_policies                     -0.007056
# Int_coop                           0.000154
# Int_assistance                     0.000000
# Coop_int_org                      -0.000282
# Int_org_sender                    -0.001326
# Int_org_sender_&_target_members    0.013696
# Length_years                      -0.001580
# Prior_relations                    0.015651
# Regime_type                        0.003617
# Regime_type2                       0.001971
# Regime_type3                       0.015672
# Political_stability_prior         -0.004719
# Political_stability_during        -0.000991
# Cost_to_target                     0.000003
# Cost_to_target_%GNP                0.001104
# Cost_to_target_per_capita          0.000081
# Trade_linkage                      0.000211
# GNP_ratio                         -0.000002
# Health_&_stability                -0.018324
# Sanction_type                     -0.004569
# Cost_to_sender                    -0.004650
# GDP_growth%5years_average         -0.001657
# Inflation%3years_average           0.000107
# Target_int_monetary_code          -0.000490
# dtype: float64
# ----------------------
# MSE est : 0.20664671805135487

# %%
## pour un alpha grand alpha = 10**10
ridge3 = Ridge(alpha = 10**10, normalize = True)
ridge3.fit(X_train, y_train)             # donnees d'apprentissage
pred3 = ridge3.predict(X_test)           # prediction sur l'échantillon test
print(" Les coeffients ")
print(pd.Series(ridge3.coef_, index = X.columns)) # les coefficients obtenus avec la méthode de Ridge
print("----------------------")
print("MSE est :",mean_squared_error(y_test, pred3))          # l'erreur MSE est plus grand quand alpha augmente
# Out:
#  Les coeffients
# Case no.b                          3.263278e-14
# Sender1                           -6.104681e-13
# Target                            -1.411159e-13
# Goal                               1.259005e-13
# US_case                           -6.079027e-13
# US_unilateral_case                -8.415013e-12
# Goal_categ                        -4.482041e-12
# First_year                        -2.001493e-14
# Last_year                         -1.405368e-13
# Comp_policies                     -3.804646e-12
# Int_coop                          -4.876448e-13
# Int_assistance                     0.000000e+00
# Coop_int_org                      -1.780335e-13
# Int_org_sender                    -4.110021e-22
# Int_org_sender_&_target_members    8.671329e-12
# Length_years                      -1.038274e-12
# Prior_relations                    9.605489e-12
# Regime_type                        2.419435e-12
# Regime_type2                       1.366377e-12
# Regime_type3                       1.170101e-11
# Political_stability_prior         -2.066649e-12
# Political_stability_during        -5.008151e-13
# Cost_to_target                     2.240562e-15
# Cost_to_target_%GNP                7.125472e-13
# Cost_to_target_per_capita          4.857000e-14
# Trade_linkage                      1.203586e-13
# GNP_ratio                         -8.792033e-16
# Health_&_stability                -8.793666e-12
# Sanction_type                     -2.281459e-12
# Cost_to_sender                    -3.123221e-12
# GDP_growth%5years_average         -1.040116e-12
# Inflation%3years_average           6.686188e-14
# Target_int_monetary_code          -3.001867e-13
# dtype: float64
# ----------------------
# MSE est : 0.21972318338050673

# %%
## alpha = 0 : ça revient à faire la régression linéaire
ridge2 = Ridge(alpha = 0, normalize = True)
ridge2.fit(X_train, y_train)             # donnees d'apprentissage
pred = ridge2.predict(X_test)            # prediction sur l'échantillon test
print(" Les coeffients ")
print(pd.Series(ridge2.coef_, index = X.columns)) # coefficients
print("----------------------")
print(mean_squared_error(y_test, pred))           # l'erreur est petite et équivaut à celle de la régression linéaire plus haut
# Out:
#  Les coeffients
# Case no.b                          3.464475e-03
# Sender1                           -1.717328e-02
# Target                            -9.023822e-04
# Goal                               1.282569e-03
# US_case                            4.232833e-01
# US_unilateral_case                -2.607728e-01
# Goal_categ                        -2.954456e-02
# First_year                        -1.119929e-02
# Last_year                         -2.798021e-03
# Comp_policies                     -5.376126e-02
# Int_coop                          -2.219841e-02
# Int_assistance                    -2.900110e-15
# Coop_int_org                       1.536379e-03
# Int_org_sender                    -8.346846e-02
# Int_org_sender_&_target_members   -1.178568e-02
# Length_years                      -3.479087e-03
# Prior_relations                    8.383769e-02
# Regime_type                        1.290037e-02
# Regime_type2                       3.093391e-02
# Regime_type3                      -1.922607e-01
# Political_stability_prior         -2.823393e-02
# Political_stability_during        -7.049730e-03
# Cost_to_target                    -1.340272e-04
# Cost_to_target_%GNP               -7.426431e-03
# Cost_to_target_per_capita          3.343351e-03
# Trade_linkage                     -2.967710e-04
# GNP_ratio                         -9.492907e-06
# Health_&_stability                -1.815076e-01
# Sanction_type                     -1.297110e-03
# Cost_to_sender                    -9.434415e-03
# GDP_growth%5years_average         -4.613298e-03
# Inflation%3years_average           6.347214e-04
# Target_int_monetary_code          -1.660371e-03
# dtype: float64
# ----------------------
# 0.217168974025087

# %% [markdown]
# #### Validation croisée

# %%
# on fait la validation croisée pour récupérer notre vrai valeur alpha ici égal à 0.005
ridgecv = RidgeCV(alphas = alphas, scoring = 'neg_mean_squared_error', normalize = True)
ridgecv.fit(X_train, y_train)
ridgecv.alpha_
# le meilleur alpha à conserver est 3.0679536367065814
# Out:
# 2.320794416806386

# %%
### Maintenant ridge avecc alphacv = 3.0679536367065814
ridge4 = Ridge(alpha = ridgecv.alpha_, normalize = True)
ridge4.fit(X_train, y_train)
print("---------------------------")
pred = ridge4.predict(X_test)
#print(pred)
print(" Les coeffients ")
print(pd.Series(ridge4.coef_, index = X.columns))
print("---------------------------")
print("MSE est : ", mean_squared_error(y_test, pred))  # Comme notre valeur alpha est bonne l'erreur est petite et équivaut de 0.0005
# c le modèle final de Ridge qui est retenu
# Out:
# ---------------------------
#  Les coeffients
# Goal_categ                        -0.154634
# Comp_policies                     -0.081189
# Int_coop                           0.024318
# Int_assistance                     0.000000
# Coop_int_org                       0.002699
# Int_org_sender_&_target_members    0.288347
# Length_years                      -0.003189
# Prior_relations                    0.168054
# Regime_type                        0.038209
# Regime_type2                       0.020249
# Regime_type3                       0.155474
# Political_stability_prior         -0.019111
# Political_stability_during        -0.003563
# Cost_to_target                    -0.000029
# Cost_to_target_%GNP                0.006317
# Cost_to_target_per_capita          0.000198
# Trade_linkage                      0.003975
# GNP_ratio                         -0.000011
# Health_&_stability                -0.225041
# Sanction_type                     -0.103864
# Cost_to_sender                    -0.059801
# GDP_growth%5years_average         -0.023445
# Inflation%3years_average           0.001141
# Target_int_monetary_code          -0.008730
# Country_group                     -0.056103
# dtype: float64
# ---------------------------
# MSE est :  17.17493876174268

# %%
#print("RIDGE :")
#print("Accuracy on training set : {:.3f}".format(ridge4.score(X_train, y_train)))
#print("Accuracy on test set : {:.3f}".format(ridge4.score(X_test, y_test)))

# %% [markdown]
# ## Régression linéaire

# %%
# régression linéaire mutiple sur l'échantillon d'apprentissage puis prédiction sur l'échantillon test
#modeleReg=LinearRegression()
from sklearn.metrics import mean_squared_error
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X_train, y_train)           # réduction 
pred2 = model.predict(X_test)           # modele pour predire l'echantillon test 

#les coeffictients B0, B1, B2 du modèle linéaire
print(" Les coeffients ")
print("----------------------")
print(pd.Series(model.coef_, index = X.columns)) # Print coefficients
print("----------------------")
# la méthode des moindres carrés estime l'écart entre la valeur prédite et la valeur observée
print("MSE est :", mean_squared_error(y_test, pred2))
# Out:
#  Les coeffients
# ----------------------
# Goal_categ                        -4.925262e-01
# Comp_policies                     -2.238736e-01
# Int_coop                           1.967345e-01
# Int_assistance                    -3.847617e-15
# Coop_int_org                       2.207414e-03
# Int_org_sender_&_target_members    7.925535e-01
# Length_years                       3.774056e-02
# Prior_relations                    2.249246e-01
# Regime_type                        1.503595e-01
# Regime_type2                       1.839729e-01
# Regime_type3                      -1.167287e+00
# Political_stability_prior         -1.613708e-01
# Political_stability_during        -3.742586e-02
# Cost_to_target                    -1.178665e-03
# Cost_to_target_%GNP                9.387780e-02
# Cost_to_target_per_capita          1.167188e-02
# Trade_linkage                      9.585962e-03
# GNP_ratio                         -5.320525e-05
# Health_&_stability                -1.256938e+00
# Sanction_type                     -3.618002e-01
# Cost_to_sender                     4.003995e-01
# GDP_growth%5years_average         -6.524530e-02
# Inflation%3years_average           2.735776e-03
# Target_int_monetary_code          -3.370373e-02
# Country_group                     -1.860478e-01
# dtype: float64
# ----------------------
# MSE est : 17.581040677027115

# %%
## régression linéaire avec statsmodels

# %%
# %matplotlib inline

from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model

# %%
model = sm.OLS(y, X)
results = model.fit()
# Avec  statsmodel, on a une sortie qui ressemble beaucoup à celle de R
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:          Success score   R-squared (uncentered):                   0.778
# Model:                            OLS   Adj. R-squared (uncentered):              0.749
# Method:                 Least Squares   F-statistic:                              26.36
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):                    1.28e-46
# Time:                        03:36:22   Log-Likelihood:                         -561.97
# No. Observations:                 204   AIC:                                      1172.
# Df Residuals:                     180   BIC:                                      1252.
# Df Model:                          24
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Goal_categ                         -0.1585      0.239     -0.663      0.508      -0.630       0.313
# Comp_policies                      -0.0846      0.247     -0.343      0.732      -0.572       0.403
# Int_coop                            0.3774      0.338      1.117      0.265      -0.289       1.044
# Int_assistance                  -3.865e-15   9.04e-15     -0.427      0.670   -2.17e-14     1.4e-14
# Coop_int_org                        0.0854      0.066      1.286      0.200      -0.046       0.217
# Int_org_sender_&_target_members     0.3085      0.847      0.364      0.716      -1.363       1.980
# Length_years                       -0.0288      0.034     -0.848      0.398      -0.096       0.038
# Prior_relations                     1.2676      0.426      2.973      0.003       0.426       2.109
# Regime_type                         0.0271      0.168      0.161      0.872      -0.305       0.359
# Regime_type2                        0.2236      0.172      1.297      0.196      -0.116       0.564
# Regime_type3                       -1.1500      1.228     -0.937      0.350      -3.573       1.273
# Political_stability_prior          -0.0966      0.154     -0.626      0.532      -0.401       0.208
# Political_stability_during         -0.0426      0.038     -1.127      0.261      -0.117       0.032
# Cost_to_target                     -0.0011      0.001     -1.985      0.049      -0.002   -6.48e-06
# Cost_to_target_%GNP                 0.1536      0.090      1.708      0.089      -0.024       0.331
# Cost_to_target_per_capita           0.0093      0.009      0.977      0.330      -0.009       0.028
# Trade_linkage                       0.0169      0.011      1.601      0.111      -0.004       0.038
# GNP_ratio                       -4.001e-05   4.93e-05     -0.812      0.418      -0.000    5.73e-05
# Health_&_stability                  0.0484      0.500      0.097      0.923      -0.937       1.034
# Sanction_type                      -0.4126      0.185     -2.234      0.027      -0.777      -0.048
# Cost_to_sender                      1.0199      0.502      2.031      0.044       0.029       2.011
# GDP_growth%5years_average          -0.0042      0.072     -0.058      0.954      -0.147       0.139
# Inflation%3years_average            0.0185      0.007      2.661      0.009       0.005       0.032
# Target_int_monetary_code           -0.0170      0.011     -1.566      0.119      -0.038       0.004
# Country_group                       0.0239      0.217      0.110      0.912      -0.404       0.452
# ==============================================================================
# Omnibus:                        5.327   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.070   Jarque-Bera (JB):                4.729
# Skew:                           0.298   Prob(JB):                       0.0940
# Kurtosis:                       2.551   Cond. No.                     4.60e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.81e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### - le meileur modèle pour prédire le succès d'une santion est ridge
# #### - les caractèristiques qui influents sur succès ou échèce d'une santion sont : Prior_relations, Cost_to_target, Sanction_type, Inflation%3years_average
